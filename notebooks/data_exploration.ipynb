# %% [markdown]
# # Query Data and Database

# %%
from pathlib import Path
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

# %% [markdown]
# ## Analyze Available Data

# %%
# Path to your data_processed folder, one level up from notebooks
data_processed_path = Path("..") / "data_processed"

# Function to print file lengths for .md and .txt files recursively
def print_file_lengths(folder_path):
    for file_path in folder_path.rglob("*"):
        if file_path.suffix in [".md", ".txt"]:
            try:
                content = file_path.read_text(encoding='utf-8')
                # Length in characters
                length_chars = len(content)
                # Optional: length in lines
                length_lines = content.count('\n') + 1
                print(f"{file_path.relative_to(folder_path)}: {length_chars} chars, {length_lines} lines")
            except Exception as e:
                print(f"Could not read {file_path}: {e}")

print_file_lengths(data_processed_path)
# Out:
# github_work_readmes/robotic-arm-training_README.md: 1150 chars, 5 lines
# github_work_readmes/transformer-translation_README.md: 1112 chars, 5 lines
# github_work_readmes/tts-agent_README.md: 1126 chars, 5 lines
# github_work_readmes/langgraph-two-tool-demo_README.md: 1044 chars, 5 lines
# github_work_readmes/spam-detection_README.md: 1115 chars, 5 lines
# github_work_readmes/shopping-basket_README.md: 1039 chars, 5 lines
# medium_articles/2023-11-10 Visualizing the Q-Learning Algorithm.md: 1045 chars, 6 lines
# medium_articles/2025-08-22 Security Agent in Action Real-Time Drone Detection and Tracking with Python.md: 1158 chars, 6 lines
# medium_articles/2025-09-18 Drone Live Detection FastAPI vs Spring Boot.md: 1050 chars, 6 lines
# medium_articles/2025-08-04 Quantum Machine Learning QML A Practical Introduction with PennyLane and Qiskit.md: 1186 chars, 6 lines
# medium_articles/2023-11-08 Solving the Lunar Lander with Genetic Algorithms.md: 1081 chars, 6 lines
# medium_articles/2025-05-25 Retrieval Augmented Generation RAG with LangChain.md: 1076 chars, 6 lines
# medium_articles/2025-09-20 Building a Simple AI Assistant in Java with OpenAI API.md: 1093 chars, 6 lines
# medium_articles/2025-07-19 Building a Quantum Computing Agent The Future of AI-Powered Quantum Experimentation.md: 1156 chars, 6 lines
# medium_articles/2025-06-06 AI Legal Agent to Analyze Big Techs Tax Strategies.md: 1131 chars, 6 lines
# medium_articles/2025-08-04 Visualizing Large-Scale LiDAR Data Insights and Techniques for Drone Mapping Applications.md: 1087 chars, 6 lines
# medium_articles/2025-08-25 From Python Model to Production YOLOv8 Drone Detection with Java  Spring Boot.md: 1117 chars, 6 lines
# medium_articles/2023-11-19 AI Use Cases in the Construction Industry.md: 1373 chars, 6 lines
# medium_articles/2023-11-22 Denoising Images with Autoencoders.md: 908 chars, 6 lines
# medium_articles/2025-06-07 How to Add Animated Backgrounds to Your Data Visualizations.md: 1092 chars, 6 lines
# medium_articles/2025-05-17 LangChain for AI Agents: Legal Text Classification and Extraction.md: 1197 chars, 7 lines
# medium_articles/2023-11-21 Semantic Segmentation of the Construction Site with U-Net.md: 1066 chars, 6 lines
# github_readmes/java-ai-assistant_README.md: 961 chars, 5 lines
# github_readmes/planning-agent_README.md: 1039 chars, 5 lines
# github_readmes/quantum-computing-agent_README.md: 1098 chars, 5 lines
# github_readmes/Timer_README.md: 1006 chars, 5 lines
# github_readmes/drone-guard_README.md: 1070 chars, 5 lines
# github_readmes/python-ai-assistant_README.md: 1000 chars, 5 lines
# github_readmes/github-agent_README.md: 1009 chars, 5 lines
# github_readmes/Blackboard_README.md: 792 chars, 5 lines
# github_readmes/webscraping-agent_README.md: 923 chars, 5 lines
# github_readmes/langchain-rag_README.md: 1089 chars, 5 lines
# github_readmes/mapping-agent_README.md: 1062 chars, 5 lines
# github_readmes/legal-agent_README.md: 1078 chars, 5 lines
# github_readmes/droneguard-comparison_README.md: 1153 chars, 5 lines
# github_readmes/DjangoReactNotes_README.md: 824 chars, 16 lines
# github_readmes/research-agent-mcp_README.md: 944 chars, 5 lines
# github_readmes/VAK_README.md: 994 chars, 5 lines
# github_readmes/langchain-intro_README.md: 978 chars, 5 lines
# github_readmes/olympic-ping-pong_README.md: 1092 chars, 5 lines
# github_readmes/ai-finance-agent_README.md: 1029 chars, 5 lines
# github_readmes/animated-chart-background_README.md: 958 chars, 5 lines
# github_readmes/agents_README.md: 898 chars, 6 lines
# github_readmes/ping-pong_README.md: 991 chars, 5 lines
# github_readmes/qml-image-classification_README.md: 1128 chars, 5 lines
# github_readmes/logistics-agent_README.md: 1022 chars, 5 lines
# github_readmes/rl-dashboard_README.md: 1030 chars, 5 lines
# github_readmes/galleries-map_README.md: 303 chars, 8 lines
# github_readmes/DataDetective_README.md: 440 chars, 10 lines
# github_readmes/security-agent_README.md: 926 chars, 5 lines
# github_readmes/adversarial-ai_README.md: 1070 chars, 5 lines
# github_readmes/AIMovieAgent_README.md: 876 chars, 5 lines
# github_readmes/voice-agent_README.md: 978 chars, 5 lines
# github_readmes/email-agent_README.md: 1008 chars, 5 lines

# %% [markdown]
# ## Load Vector Store

# %%
def load_vector_store():
    """Load existing vector store."""
    persist_dir = Path("..") / "chroma_db"
    if not persist_dir.exists() or not any(persist_dir.iterdir()):
        raise FileNotFoundError(
            f"Vector store not found at {persist_dir}\n"
            "Please run: python -m src.create_database"
        )
    print("Loading vector store...")
    embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
    vector_store = Chroma(
        persist_directory=str(persist_dir),
        embedding_function=embeddings,
        collection_name="digital_twin"
    )
    print(f"✓ Loaded vector store from {persist_dir}\n")
    return vector_store

vector_store = load_vector_store()
collection = vector_store
# Out:
# Loading vector store...
# ✓ Loaded vector store from ../chroma_db

# %% [markdown]
# ## Analyze Metadata

# %%
def show_chunk_metadata(collection, num_chunks=605):
    """Prints out chunk IDs and metadata for the specified number of chunks."""
    try:
        data = collection.get(limit=num_chunks)  # use limit for performance if supported
    except Exception as e:
        print(f"Error fetching data: {e}")
        return
    total = min(num_chunks, len(data["ids"]))
    print(f"Showing metadata for {total} chunks:\n")
    for idx in range(total):
        chunk_id = data["ids"][idx]
        metadata = data["metadatas"][idx]
        print(f"Chunk {idx+1}: ID={chunk_id}, Metadata={metadata}")


show_chunk_metadata(collection, num_chunks=605)
# Out:
# Showing metadata for 55 chunks:
#
# Chunk 1: ID=c2f0297d-a21d-4f55-abb6-6673880c7bb0, Metadata={'type': 'profile', 'source': 'linkedin'}
# Chunk 2: ID=7ad5eb24-2a0e-43de-b37f-8f5f8050d0c2, Metadata={'file': 'java-ai-assistant_README.md', 'type': 'project', 'source': 'github'}
# Chunk 3: ID=9c2f777d-612a-4959-951b-897dbf770b83, Metadata={'source': 'github', 'file': 'planning-agent_README.md', 'type': 'project'}
# Chunk 4: ID=71cf6106-d913-44e1-a8a5-6a55f2125c61, Metadata={'type': 'project', 'file': 'quantum-computing-agent_README.md', 'source': 'github'}
# Chunk 5: ID=f7ed4073-9a4d-4add-811f-fcd15c0b2689, Metadata={'type': 'project', 'source': 'github', 'file': 'Timer_README.md'}
# Chunk 6: ID=fc328fb9-6ee1-4ed4-935d-b0ad48b123f5, Metadata={'type': 'project', 'source': 'github', 'file': 'drone-guard_README.md'}
# Chunk 7: ID=c5b25e2f-7d43-419e-a7fe-d13311e96fa6, Metadata={'file': 'python-ai-assistant_README.md', 'source': 'github', 'type': 'project'}
# Chunk 8: ID=020c131c-fdc6-423d-8469-3d2bba073732, Metadata={'source': 'github', 'file': 'github-agent_README.md', 'type': 'project'}
# Chunk 9: ID=75801aaf-4a78-409d-a808-132a79676145, Metadata={'file': 'Blackboard_README.md', 'type': 'project', 'source': 'github'}
# Chunk 10: ID=24e062b6-258f-420f-892a-5db3f65f1511, Metadata={'type': 'project', 'file': 'webscraping-agent_README.md', 'source': 'github'}
# Chunk 11: ID=6fe2f231-d553-4557-b033-2e7d4ff85a1e, Metadata={'source': 'github', 'type': 'project', 'file': 'langchain-rag_README.md'}
# Chunk 12: ID=dbe019f4-2791-41d8-b105-7ad7f7c13db7, Metadata={'source': 'github', 'file': 'mapping-agent_README.md', 'type': 'project'}
# Chunk 13: ID=5b7f1e87-5e7d-4045-9f23-7f7682848bb2, Metadata={'source': 'github', 'file': 'legal-agent_README.md', 'type': 'project'}
# Chunk 14: ID=109abef5-4a49-4227-935b-35533e7fbe94, Metadata={'source': 'github', 'type': 'project', 'file': 'droneguard-comparison_README.md'}
# Chunk 15: ID=fc38cdaa-30cc-4b52-b03a-3290b3737ff3, Metadata={'type': 'project', 'source': 'github', 'file': 'DjangoReactNotes_README.md'}
# Chunk 16: ID=836bfad8-ba57-425f-8d86-bf6e167df54e, Metadata={'type': 'project', 'source': 'github', 'file': 'research-agent-mcp_README.md'}
# Chunk 17: ID=f6e1e0d0-c616-4017-8558-1301308df620, Metadata={'file': 'VAK_README.md', 'type': 'project', 'source': 'github'}
# Chunk 18: ID=88d38256-7dbc-4649-97d6-4b0cfe7632e6, Metadata={'type': 'project', 'source': 'github', 'file': 'langchain-intro_README.md'}
# Chunk 19: ID=b8a0a72c-6daf-499a-8add-cb77cfa82452, Metadata={'type': 'project', 'file': 'olympic-ping-pong_README.md', 'source': 'github'}
# Chunk 20: ID=61ea3990-a894-4033-adb4-12d774abf1c6, Metadata={'type': 'project', 'source': 'github', 'file': 'ai-finance-agent_README.md'}
# Chunk 21: ID=593ca417-7ea1-49e3-a4e4-c454603473bb, Metadata={'file': 'animated-chart-background_README.md', 'source': 'github', 'type': 'project'}
# Chunk 22: ID=3aad0b5f-2dd3-444e-842e-a08950d9a76a, Metadata={'type': 'project', 'file': 'agents_README.md', 'source': 'github'}
# Chunk 23: ID=0d7f5cd9-bb95-404f-bb49-fe1dd0da29fe, Metadata={'source': 'github', 'file': 'ping-pong_README.md', 'type': 'project'}
# Chunk 24: ID=041b9243-f5ff-4651-9c06-7df54c47ad9d, Metadata={'type': 'project', 'file': 'qml-image-classification_README.md', 'source': 'github'}
# Chunk 25: ID=d85f43f8-43df-428b-aa74-84e5b462990a, Metadata={'source': 'github', 'type': 'project', 'file': 'logistics-agent_README.md'}
# Chunk 26: ID=ac18b58d-7265-4acc-b99f-091317e5efaa, Metadata={'source': 'github', 'file': 'rl-dashboard_README.md', 'type': 'project'}
# Chunk 27: ID=3b47c62a-9b7d-4878-aedf-5f660fb5ba95, Metadata={'type': 'project', 'file': 'galleries-map_README.md', 'source': 'github'}
# Chunk 28: ID=006613fb-a273-49c6-a08a-1400b982205f, Metadata={'file': 'DataDetective_README.md', 'source': 'github', 'type': 'project'}
# Chunk 29: ID=957cc673-4b1f-4523-b145-03324eeddd2c, Metadata={'type': 'project', 'file': 'security-agent_README.md', 'source': 'github'}
# Chunk 30: ID=128f370c-17fd-42ee-ac9c-43b18a21057a, Metadata={'source': 'github', 'file': 'adversarial-ai_README.md', 'type': 'project'}
# Chunk 31: ID=55c73395-d911-46f4-a5cb-1772960dc8f8, Metadata={'source': 'github', 'file': 'AIMovieAgent_README.md', 'type': 'project'}
# Chunk 32: ID=0d4ce0da-07e6-4d6f-ab00-3fe31829c6bb, Metadata={'file': 'voice-agent_README.md', 'source': 'github', 'type': 'project'}
# Chunk 33: ID=0c6c6bcd-cfb3-444b-b5b2-1f145f0015e6, Metadata={'file': 'email-agent_README.md', 'source': 'github', 'type': 'project'}
# Chunk 34: ID=3764ec92-6b13-4ed0-9d94-9851c486a960, Metadata={'source': 'github', 'type': 'project', 'file': 'robotic-arm-training_README.md'}
# Chunk 35: ID=cb1b3f64-2734-46c9-9eb5-a605a18369b5, Metadata={'source': 'github', 'file': 'transformer-translation_README.md', 'type': 'project'}
# Chunk 36: ID=b5855209-b753-4be4-8d68-4d9722315e73, Metadata={'file': 'tts-agent_README.md', 'source': 'github', 'type': 'project'}
# Chunk 37: ID=df81aefd-b2ef-48c6-aacf-6ec1b55753cf, Metadata={'type': 'project', 'source': 'github', 'file': 'langgraph-two-tool-demo_README.md'}
# Chunk 38: ID=ecabe8f9-6e8e-43f0-b1da-a6ca43bbec4c, Metadata={'file': 'spam-detection_README.md', 'type': 'project', 'source': 'github'}
# Chunk 39: ID=bcc0fc71-fe1b-4399-be3e-22cbf0f9a53f, Metadata={'source': 'github', 'file': 'shopping-basket_README.md', 'type': 'project'}
# Chunk 40: ID=a7b4d0f2-9952-497c-be93-b05cb43d4ae6, Metadata={'source': 'medium', 'type': 'article', 'file': '2023-11-10 Visualizing the Q-Learning Algorithm.md'}
# Chunk 41: ID=c507627e-bed3-4f3f-a636-57b484faf6e5, Metadata={'source': 'medium', 'type': 'article', 'file': '2025-08-22 Security Agent in Action Real-Time Drone Detection and Tracking with Python.md'}
# Chunk 42: ID=49d2d8b4-dfd0-44c8-9732-4bef7ccdc276, Metadata={'file': '2025-09-18 Drone Live Detection FastAPI vs Spring Boot.md', 'source': 'medium', 'type': 'article'}
# Chunk 43: ID=7114388e-b5e4-4210-8152-9ef9a68fcee3, Metadata={'source': 'medium', 'type': 'article', 'file': '2025-08-04 Quantum Machine Learning QML A Practical Introduction with PennyLane and Qiskit.md'}
# Chunk 44: ID=bc6e60fb-f7ba-4012-873f-d4dd17f9d07e, Metadata={'file': '2023-11-08 Solving the Lunar Lander with Genetic Algorithms.md', 'source': 'medium', 'type': 'article'}
# Chunk 45: ID=66a75724-af1b-4800-bfaa-e0679aa4a5c5, Metadata={'file': '2025-05-25 Retrieval Augmented Generation RAG with LangChain.md', 'type': 'article', 'source': 'medium'}
# Chunk 46: ID=3437496c-a019-44c5-9145-ef4bb8d38689, Metadata={'source': 'medium', 'file': '2025-09-20 Building a Simple AI Assistant in Java with OpenAI API.md', 'type': 'article'}
# Chunk 47: ID=e01f2dac-6c25-40c2-a237-0f08b9f604f3, Metadata={'type': 'article', 'file': '2025-07-19 Building a Quantum Computing Agent The Future of AI-Powered Quantum Experimentation.md', 'source': 'medium'}
# Chunk 48: ID=fd0e59b1-c046-4c70-b36e-fd91cf862227, Metadata={'type': 'article', 'file': '2025-06-06 AI Legal Agent to Analyze Big Techs Tax Strategies.md', 'source': 'medium'}
# Chunk 49: ID=d58fafb9-907c-4b9b-81e6-d38a9054a02f, Metadata={'source': 'medium', 'file': '2025-08-04 Visualizing Large-Scale LiDAR Data Insights and Techniques for Drone Mapping Applications.md', 'type': 'article'}
# Chunk 50: ID=f1b039ed-19c4-4133-a376-e9944def6585, Metadata={'type': 'article', 'source': 'medium', 'file': '2025-08-25 From Python Model to Production YOLOv8 Drone Detection with Java  Spring Boot.md'}
# Chunk 51: ID=1d685c6c-927d-44f1-862d-5b0103a8588f, Metadata={'file': '2023-11-19 AI Use Cases in the Construction Industry.md', 'source': 'medium', 'type': 'article'}
# Chunk 52: ID=fd613e28-4de8-4410-8f3f-5681810e8330, Metadata={'source': 'medium', 'type': 'article', 'file': '2023-11-22 Denoising Images with Autoencoders.md'}
# Chunk 53: ID=45d06b10-e001-4d07-a972-92c1a567472e, Metadata={'type': 'article', 'source': 'medium', 'file': '2025-06-07 How to Add Animated Backgrounds to Your Data Visualizations.md'}
# Chunk 54: ID=19101aa0-c17c-4f4a-a3f2-e3efb190f298, Metadata={'source': 'medium', 'type': 'article', 'file': '2025-05-17 LangChain for AI Agents: Legal Text Classification and Extraction.md'}
# Chunk 55: ID=33b715a1-977c-4107-806b-05c8dd0d5609, Metadata={'file': '2023-11-21 Semantic Segmentation of the Construction Site with U-Net.md', 'source': 'medium', 'type': 'article'}

# %% [markdown]
# ## Analyze Chunks

# %%
def show_selected_chunks(collection, selected_indices):
    data = collection.get()
    total_chunks = len(data["ids"])
    
    for idx in selected_indices:
        if 0 <= idx < total_chunks:
            chunk_id = data["ids"][idx]
            metadata = data["metadatas"][idx]
            content = data["documents"][idx]
            print(f"Chunk {idx}: ID={chunk_id}")
            print(f"Metadata: {metadata}")
            print(f"Content:\n{content}\n{'-'*40}\n")
        else:
            print(f"Index {idx} out of range (0 to {total_chunks - 1})")


show_selected_chunks(collection, selected_indices=[0, 1, 2, 3, 4, 55])
# Out:
# Chunk 0: ID=c2f0297d-a21d-4f55-abb6-6673880c7bb0
# Metadata: {'type': 'profile', 'source': 'linkedin'}
# Content:
# {
#   "profile": {
#     "link": [
#       "https://de.linkedin.com/in/yauheniya-varabyova"
#     ],
#     "tagline": [
#       "AI",
#       "BI",
#       "Data Science",
#       "LLM",
#       "ML"
#     ],
#     "experience": [
#       {
#         "company": "adesso SE",
#         "employment_type": "Full-time",
#         "start_date": "Oct 2025",
#         "end_date": "Present",
#         "location": "Berlin, Germany",
#         "title": "Senior Consultant",
#         "skills": [
#           "AI",
#           "Agents",
#           "ML"
#         ]
#       },
#       {
#         "company": "Self-employed",
#         "employment_type": "Full-time",
#         "start_date": "Oct 2023",
#         "end_date": "Sep 2025",
#         "location": "Berlin, Germany",
#         "title": "AI Engineer",
#         "skills": [
#           "AI",
#           "Data Analysis",
#           "Large Language Models (LLM)",
#           "ML",
#           "Software Development"
#         ]
#       },
#       {
#         "company": "Detecon International",
#         "employment_type": "Full-time",
#         "start_date": "Sep 2021",
#         "end_date": "Sep 2023",
#         "location": "Berlin",
#         "title": "Consultant",
#         "description": "Consultant for AI & Big Data",
#         "skills": [
#           "AI",
#           "Data Science",
#           "ML",
#           "Data Management",
#           "Strategy"
#         ]
#       },
#       {
#         "company": "Self-employed",
#         "employment_type": "Full-time",
#         "start_date": "Feb 2019",
#         "end_date": "Aug 2021",
#         "location": "Berlin",
#         "title": "Business Analyst",
#         "description": "Independent Business Analyst in Tech and Digitalisation",
#         "skills": [
#           "Benchmarking",
#           "IT Business Analysis",
#           "Robotics"
#         ]
#       },
#       {
#         "company": "Federal Ministry of Health",
#         "employment_type": "Full-time",
#         "start_date": "Feb 2017",
#         "end_date": "Feb 2019",
#         "location": "Berlin and Surroundings, Germany",
#         "title": "Scientific Counsellor",
#         "description": "Qualitative and Quantitative Analysis of the Health Care System",
#         "skills": [
#           "Data Analysis",
#           "Benchmarking",
#           "Health Politics"
#         ]
#       },
#       {
#         "company": "Hamburg Center for Health Economics",
#         "employment_type": "Full-time",
#         "start_date": "2012",
#         "end_date": "2016",
#         "location": "Hamburg",
#         "title": "Research Associate",
#         "description": "Research Projects in the Hospital and Medical Device Sectors",
#         "skills": [
#           "Benchmarking",
#           "Efficiency Analysis",
#           "HTA"
#         ]
#       }
#     ],
#     "education": [
#       {
#         "institution": "University of Artificial Intelligence",
#         "degree": "Diploma",
#         "field_of_study": "Data Science, Neural Networks, Machine Learning, and AI",
#         "start_date": "May 2021",
#         "end_date": "Jun 2022",
#         "description": "Developing neural networks and genetic algorithms to solve business use cases. Diploma project: \"Forecasting Energy Consumption in the Manufacturing Industry: Multiple Linear Regression and Artificial Neural Networks\""
#       },
#       {
#         "institution": "University of Hamburg",
#         "degree": "Dr. rer. oec., Management in Health Care",
#         "start_date": "2012",
#         "end_date": "2016",
#         "description": "Innovative Nonparametric Approaches to Measuring Efficiency in Health Care. Challenges in the Assessment of Medical Devices: The MedtecHTA Project"
#       },
#       {
#         "institution": "University of Hamburg",
#         "degree": "Master of Science (MS), Economics",
#         "start_date": "2010",
#         "end_date": "2012",
#         "description": "Master Thesis: \u201cInternational Comparisons of the Technical Efficiency of the Hospital Sector: Panel Data Analysis of OECD Countries Using Parametric and Non-Parametric Approaches\u201d"
#       },
#       {
#         "institution": "LCC International University, Lithuania",
#         "degree": "Bachelor of Arts (BA), Business Administration",
#         "start_date": "Sep 2006",
#         "end_date": "May 2010",
#         "description": "Commendation for the most outstanding Bachelor Thesis in Economics. Minor in Psychology"
#       }
#     ]
#   }
# }
# ----------------------------------------
#
# Chunk 1: ID=7ad5eb24-2a0e-43de-b37f-8f5f8050d0c2
# Metadata: {'file': 'java-ai-assistant_README.md', 'type': 'project', 'source': 'github'}
# Content:
# Java AI Assistant
#
# github.com/yauheniya-ai: Agentic AI • BI • Cybersecurity • Data Science • Genetic Algorithms • Neural Networks • Quantum Computing • Robotics
#
# This project is a minimal AI chatbot web application built with Java Spring Boot and the OpenAI API. Users can select an AI model from a dropdown menu, type questions, and receive responses in a clean, simple web interface. The app demonstrates integrating AI into a Java backend with a minimal frontend, highlighting Spring Boot controllers, service layers, and API communication. Key components include AiAssistantApplication.java (main entry point), AssistantController.java (handles POST requests), and OpenAiAssistantService.java (calls OpenAI API). The project uses Maven for dependency management and configuration via application.yml. It requires Java 21, a valid OpenAI API key, and supports quick setup, making it ideal for experimenting with AI-powered applications in the Java ecosystem.
# ----------------------------------------
#
# Chunk 2: ID=9c2f777d-612a-4959-951b-897dbf770b83
# Metadata: {'file': 'planning-agent_README.md', 'type': 'project', 'source': 'github'}
# Content:
# Planning Agent: Multi-Agent Project Planning
#
# github.com/yauheniya-ai: Agentic AI • BI • Cybersecurity • Data Science • Genetic Algorithms • Neural Networks • Quantum Computing • Robotics
#
# This project implements a multi-agent system for automated project planning and resource allocation using the CrewAI framework. The system decomposes complex projects into actionable tasks, estimates time and resources, and optimally assigns work to team members. It generates structured project plans with milestones, deliverables, and Gantt chart visualizations. Architecture includes a Project Planning Agent (task breakdown and dependencies), Estimation Agent (time/resource prediction), and Resource Allocation Agent (task assignment). Configurable via YAML files and environment variables, it supports Python 3.12+, OpenAI API, Plotly, and Kaleido. Example demonstrates planning for an aerospace "Electric Motor Production Facility," illustrating multi-stakeholder industrial project management, timeline visualization, and workflow automation.
# ----------------------------------------
#
# Chunk 3: ID=71cf6106-d913-44e1-a8a5-6a55f2125c61
# Metadata: {'file': 'quantum-computing-agent_README.md', 'source': 'github', 'type': 'project'}
# Content:
# AI Quantum Computing Agent: LLM-Driven Quantum Circuits
#
# github.com/yauheniya-ai: Agentic AI • BI • Cybersecurity • Data Science • Genetic Algorithms • Neural Networks • Quantum Computing • Robotics
#
# This project implements an AI-powered agent that interprets natural language instructions, selects quantum operations via OpenAI GPT (LLM), and executes them using Qiskit. It supports predefined circuits such as Hadamard, Pauli-X, RY rotations, CNOT, Bell states, Toffoli, and Fredkin gates. The agent visualizes results as circuit diagrams, measurement histograms, and Bloch sphere representations, enabling interactive exploration of quantum states. Built with LangChain/LangGraph, Qiskit Aer, and Matplotlib, the workflow parses user prompts, uses LLM reasoning to construct circuits, simulates quantum execution, and generates visual outputs. The system runs on Python 3.9+, with configurable prompts and API keys, allowing users to experiment with quantum operations via a natural language interface. Demonstrates integration of AI reasoning with quantum computation for learning and research.
# ----------------------------------------
#
# Chunk 4: ID=f7ed4073-9a4d-4add-811f-fcd15c0b2689
# Metadata: {'type': 'project', 'source': 'github', 'file': 'Timer_README.md'}
# Content:
# React Clock and Timer App
#
# github.com/yauheniya-ai: Agentic AI • BI • Cybersecurity • Data Science • Genetic Algorithms • Neural Networks • Quantum Computing • Robotics
#
# A React-based web app that combines a live clock and a countdown timer. The clock displays the current time in 12-hour or 24-hour formats, toggleable by the user. The timer allows setting countdowns with minutes and seconds, playing a sound on completion. The layout is responsive, positioning the clock at the top-right and timer at the bottom-left of the browser. Built with React hooks (useState, useEffect, useRef), Vite for fast builds, JavaScript, and CSS. Users can customize styles or replace the timer sound. The project structure separates main components (ClockTimer.jsx, App.jsx) and assets (public/timer-sound.mp3). Installation involves cloning the repo, installing dependencies, and running the Vite dev server. This lightweight app is ideal for learning React state management, event handling, and component structuring.
# ----------------------------------------
#
# Index 55 out of range (0 to 54)
